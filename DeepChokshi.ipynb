# %%
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris()

# %%
plt.plot(data,target)
# Out:
# [<matplotlib.lines.Line2D at 0x2c111d10848>,
#  <matplotlib.lines.Line2D at 0x2c111cf95c8>,
#  <matplotlib.lines.Line2D at 0x2c111d10888>,
#  <matplotlib.lines.Line2D at 0x2c111d10988>]

# %%
featuresAll=[]
features = iris.data[: , [0,1,2,3]]
features.shape
# Out:
# (150, 4)

# %%
targets = iris.target
targets.reshape(targets.shape[0],-1)
targets.shape
# Out:
# (150,)

# %%
for observation in features:
    featuresAll.append([observation[0] + observation[1] + observation[2] + observation[3]])

# %%
plt.scatter(featuresAll, target, color='red', alpha =1.0)
plt.title('Iris Dataset scatter Plot')
plt.xlabel('Features')
plt.ylabel('Targets')
# Out:
# Text(0, 0.5, 'Targets')

# %%
plt.plot(featuresAll, target)

# %%
plt.hist(featuresAll)
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)
